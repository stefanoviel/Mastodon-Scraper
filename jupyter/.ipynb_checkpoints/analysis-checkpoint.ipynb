# %%
import json
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_json('../data/instances.json')
df = df.transpose()
df
# Out:
#                                                                            error  \
# peertube.livingutopia.org      400 Client Error: Bad Request for url: https:/...
# social.fingerprintsoftware.ca                                                NaN
# friendica.dupreez.id.au        HTTPSConnectionPool(host='friendica.dupreez.id...
# zerojanvier.fr                 HTTPSConnectionPool(host='zerojanvier.fr', por...
# lazybear.io                    404 Client Error: Not Found for url: https://l...
# ...                                                                          ...
# mastodon.mashi.ro              HTTPSConnectionPool(host='mastodon.mashi.ro', ...
# pix.social.synesthesia.co.uk   HTTPSConnectionPool(host='pix.social.synesthes...
# mastodon.ngen15.tv             HTTPSConnectionPool(host='mastodon.ngen15.tv',...
# social.openinfra.dev           HTTPSConnectionPool(host='social.openinfra.dev...
# mastodon.tlpfam.com            HTTPSConnectionPool(host='mastodon.tlpfam.com'...
#
#                                                                  uri  \
# peertube.livingutopia.org                                        NaN
# social.fingerprintsoftware.ca  https://social.fingerprintsoftware.ca
# friendica.dupreez.id.au                                          NaN
# zerojanvier.fr                                                   NaN
# lazybear.io                                                      NaN
# ...                                                              ...
# mastodon.mashi.ro                                                NaN
# pix.social.synesthesia.co.uk                                     NaN
# mastodon.ngen15.tv                                               NaN
# social.openinfra.dev                                             NaN
# mastodon.tlpfam.com                                              NaN
#
#                                                              title  \
# peertube.livingutopia.org                                      NaN
# social.fingerprintsoftware.ca  Fingerprint Software Friendica Node
# friendica.dupreez.id.au                                        NaN
# zerojanvier.fr                                                 NaN
# lazybear.io                                                    NaN
# ...                                                            ...
# mastodon.mashi.ro                                              NaN
# pix.social.synesthesia.co.uk                                   NaN
# mastodon.ngen15.tv                                             NaN
# social.openinfra.dev                                           NaN
# mastodon.tlpfam.com                                            NaN
#
#                               short_description description  \
# peertube.livingutopia.org                   NaN         NaN
# social.fingerprintsoftware.ca
# friendica.dupreez.id.au                     NaN         NaN
# zerojanvier.fr                              NaN         NaN
# lazybear.io                                 NaN         NaN
# ...                                         ...         ...
# mastodon.mashi.ro                           NaN         NaN
# pix.social.synesthesia.co.uk                NaN         NaN
# mastodon.ngen15.tv                          NaN         NaN
# social.openinfra.dev                        NaN         NaN
# mastodon.tlpfam.com                         NaN         NaN
#
#                                                          email  \
# peertube.livingutopia.org                                  NaN
# social.fingerprintsoftware.ca  jonathan@fingerprintsoftware.ca
# friendica.dupreez.id.au                                    NaN
# zerojanvier.fr                                             NaN
# lazybear.io                                                NaN
# ...                                                        ...
# mastodon.mashi.ro                                          NaN
# pix.social.synesthesia.co.uk                               NaN
# mastodon.ngen15.tv                                         NaN
# social.openinfra.dev                                       NaN
# mastodon.tlpfam.com                                        NaN
#
#                                                              version  urls  \
# peertube.livingutopia.org                                        NaN   NaN
# social.fingerprintsoftware.ca  2.8.0 (compatible; Friendica 2023.01)  None
# friendica.dupreez.id.au                                          NaN   NaN
# zerojanvier.fr                                                   NaN   NaN
# lazybear.io                                                      NaN   NaN
# ...                                                              ...   ...
# mastodon.mashi.ro                                                NaN   NaN
# pix.social.synesthesia.co.uk                                     NaN   NaN
# mastodon.ngen15.tv                                               NaN   NaN
# social.openinfra.dev                                             NaN   NaN
# mastodon.tlpfam.com                                              NaN   NaN
#
#                                                                            stats  \
# peertube.livingutopia.org                                                    NaN
# social.fingerprintsoftware.ca  {'user_count': 0, 'status_count': 0, 'domain_c...
# friendica.dupreez.id.au                                                      NaN
# zerojanvier.fr                                                               NaN
# lazybear.io                                                                  NaN
# ...                                                                          ...
# mastodon.mashi.ro                                                            NaN
# pix.social.synesthesia.co.uk                                                 NaN
# mastodon.ngen15.tv                                                           NaN
# social.openinfra.dev                                                         NaN
# mastodon.tlpfam.com                                                          NaN
#
#                                                            thumbnail  ...  \
# peertube.livingutopia.org                                        NaN  ...
# social.fingerprintsoftware.ca  https://social.fingerprintsoftware.ca  ...
# friendica.dupreez.id.au                                          NaN  ...
# zerojanvier.fr                                                   NaN  ...
# lazybear.io                                                      NaN  ...
# ...                                                              ...  ...
# mastodon.mashi.ro                                                NaN  ...
# pix.social.synesthesia.co.uk                                     NaN  ...
# mastodon.ngen15.tv                                               NaN  ...
# social.openinfra.dev                                             NaN  ...
# mastodon.tlpfam.com                                              NaN  ...
#
#                               thumbnail_description feature_quote  \
# peertube.livingutopia.org                       NaN           NaN
# social.fingerprintsoftware.ca                   NaN           NaN
# friendica.dupreez.id.au                         NaN           NaN
# zerojanvier.fr                                  NaN           NaN
# lazybear.io                                     NaN           NaN
# ...                                             ...           ...
# mastodon.mashi.ro                               NaN           NaN
# pix.social.synesthesia.co.uk                    NaN           NaN
# mastodon.ngen15.tv                              NaN           NaN
# social.openinfra.dev                            NaN           NaN
# mastodon.tlpfam.com                             NaN           NaN
#
#                               description_source login_message  \
# peertube.livingutopia.org                    NaN           NaN
# social.fingerprintsoftware.ca                NaN           NaN
# friendica.dupreez.id.au                      NaN           NaN
# zerojanvier.fr                               NaN           NaN
# lazybear.io                                  NaN           NaN
# ...                                          ...           ...
# mastodon.mashi.ro                            NaN           NaN
# pix.social.synesthesia.co.uk                 NaN           NaN
# mastodon.ngen15.tv                           NaN           NaN
# social.openinfra.dev                         NaN           NaN
# mastodon.tlpfam.com                          NaN           NaN
#
#                               post_character_limit blockchains  \
# peertube.livingutopia.org                      NaN         NaN
# social.fingerprintsoftware.ca                  NaN         NaN
# friendica.dupreez.id.au                        NaN         NaN
# zerojanvier.fr                                 NaN         NaN
# lazybear.io                                    NaN         NaN
# ...                                            ...         ...
# mastodon.mashi.ro                              NaN         NaN
# pix.social.synesthesia.co.uk                   NaN         NaN
# mastodon.ngen15.tv                             NaN         NaN
# social.openinfra.dev                           NaN         NaN
# mastodon.tlpfam.com                            NaN         NaN
#
#                               ipfs_gateway_url fedibird_capabilities usage  \
# peertube.livingutopia.org                  NaN                   NaN   NaN
# social.fingerprintsoftware.ca              NaN                   NaN   NaN
# friendica.dupreez.id.au                    NaN                   NaN   NaN
# zerojanvier.fr                             NaN                   NaN   NaN
# lazybear.io                                NaN                   NaN   NaN
# ...                                        ...                   ...   ...
# mastodon.mashi.ro                          NaN                   NaN   NaN
# pix.social.synesthesia.co.uk               NaN                   NaN   NaN
# mastodon.ngen15.tv                         NaN                   NaN   NaN
# social.openinfra.dev                       NaN                   NaN   NaN
# mastodon.tlpfam.com                        NaN                   NaN   NaN
#
#                               media_attachments
# peertube.livingutopia.org                   NaN
# social.fingerprintsoftware.ca               NaN
# friendica.dupreez.id.au                     NaN
# zerojanvier.fr                              NaN
# lazybear.io                                 NaN
# ...                                         ...
# mastodon.mashi.ro                           NaN
# pix.social.synesthesia.co.uk                NaN
# mastodon.ngen15.tv                          NaN
# social.openinfra.dev                        NaN
# mastodon.tlpfam.com                         NaN
#
# [58278 rows x 40 columns]

# %%
# count error, real instances and error type
# number of user per instance, toots

# %%
plt.bar(['Error', 'Returned Info'], [df['error'].count(), df['uri'].count()], width = 0.4)
print(df['error'].count(), df['uri'].count())
plt.show()
# Out:
# 46281 11997

# %%
errors = {}

nonan = df['error'].dropna()

errors['HTTPSConnectionPool'] = nonan.str.contains('HTTPSConnectionPool').sum()
errors['Connection aborted.'] = nonan.str.contains('Connection aborted.').sum()
errors['400'] = nonan.str.contains('400 Client Error').sum()
errors['404'] = nonan.str.contains('404 Client Error').sum()
errors['526'] = nonan.str.contains('526').sum()
errors['502'] = nonan.str.contains('502').sum()
errors['503'] = nonan.str.contains('503').sum()
errors['401'] = nonan.str.contains('401').sum()
errors['403'] = nonan.str.contains('403').sum()
errors['Expecting value'] = nonan.str.contains('Expecting value').sum()
errors['Expecting value']
# Out:
# 918

# %%
nonan[(~nonan.str.contains("HTTPSConnectionPool")) & (~nonan.str.contains("502")) & (~nonan.str.contains("503")) & (~nonan.str.contains("403")) & (~nonan.str.contains("404")) & (~nonan.str.contains("526")) & (~nonan.str.contains("401")) & (~nonan.str.contains("400"))].iloc[0]
# Out:
# 'Expecting value: line 6 column 3 (char 7)'

# %%
nonan[nonan.str.contains("404")].iloc[5]
# Out:
# '404 Client Error: Not Found for url: https://hub.bierzilla.fr/api/v1/instance'

# %%
plt.bar(list(errors.keys()), list(errors.values()))
plt.xticks( rotation= 90)
plt.show()

#  HTTPSConnectionPool: Max retries exceeded with url => trying them manually leads to error as well OR they could 
# could be hosted in the same server and I exceed the number of requests there
# 400 => bad request, seems like like that function wasn't implemented
# 404 => Not implemented

# %%
nonanstats = df.stats.dropna()
user_count = nonanstats.apply(lambda x : (eval(str(x))['user_count']))
status_count = nonanstats.apply(lambda x : (eval(str(x))['status_count']))
domain_count = nonanstats.apply(lambda x : (eval(str(x)).get('domain_count')))

# %%
user_count = user_count.dropna().apply(lambda x : int(x))
user_count = user_count.sort_values(ascending= False)
plt.plot(np.emath.logn(10, user_count))
plt.title('user count')
plt.ylabel('log(number users)', fontsize=18)
print(user_count.iloc[:10])
plt.show()
# Out:
# mastodon.social        1032973
# pawoo.net               847852
# switter.at              435490
# gamethattune.club       300966
# baraag.net              293859
# mastodon.cloud          247604
# soc.jae.fi              247204
# mk.anarchyfox.space     198487
# mstdn.social            193819
# www.foxyhole.io         186087
# Name: stats, dtype: int64
# /home/stefano/anaconda3/lib/python3.9/site-packages/numpy/lib/scimath.py:377: RuntimeWarning: divide by zero encountered in log
#   return nx.log(x)/nx.log(n)

# %%
status_count = status_count.dropna().apply(lambda x : int(x))
status_count = status_count.sort_values(ascending= False)
plt.plot(np.emath.logn(10, status_count))
plt.title('status count')
plt.ylabel('log(status count)', fontsize=18)
plt.show()
# Out:
# /home/stefano/anaconda3/lib/python3.9/site-packages/numpy/lib/scimath.py:377: RuntimeWarning: divide by zero encountered in log
#   return nx.log(x)/nx.log(n)
# /home/stefano/anaconda3/lib/python3.9/site-packages/numpy/lib/scimath.py:377: RuntimeWarning: invalid value encountered in true_divide
#   return nx.log(x)/nx.log(n)
# /home/stefano/anaconda3/lib/python3.9/site-packages/matplotlib/cbook/__init__.py:1333: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)

# %%
domain_count = domain_count.dropna().apply(lambda x : int(x))
domain_count = domain_count.sort_values(ascending= False)
plt.plot(np.emath.logn(10, domain_count))
plt.title('domain count')
plt.ylabel('log(domain count)', fontsize=18)
plt.show()
# Out:
# /home/stefano/anaconda3/lib/python3.9/site-packages/numpy/lib/scimath.py:377: RuntimeWarning: divide by zero encountered in log
#   return nx.log(x)/nx.log(n)

# %%
df = pd.read_json('../data/users.json')
df = df.transpose()
df
# Out:
#                                                          id         username  \
# https://mastodon.social/@Gargron                          1          Gargron
# https://mastodon.social/@thedextriarchy              225094   thedextriarchy
# https://mastodon.online/@darth           110103726548873661            darth
# https://mastodon.online/@justinling      109291667985123090       justinling
# https://c18.masto.host/@grubstreetwomen  110098523946534892  grubstreetwomen
# ...                                                     ...              ...
# https://mastodon.xyz/@Ashkendo           109741032897278411         Ashkendo
# https://hachyderm.io/@collinbanko        109741031015998392      collinbanko
# https://starside.social/@beorn           109741022459884162            beorn
# https://mastodon.social/@shourijo        109740932000090188         shourijo
# https://iconfactory.world/@support       109740289815470390          support
#
#                                                                    acct  \
# https://mastodon.social/@Gargron                                Gargron
# https://mastodon.social/@thedextriarchy                  thedextriarchy
# https://mastodon.online/@darth                    darth@mastodon.online
# https://mastodon.online/@justinling          justinling@mastodon.online
# https://c18.masto.host/@grubstreetwomen  grubstreetwomen@c18.masto.host
# ...                                                                 ...
# https://mastodon.xyz/@Ashkendo                    Ashkendo@mastodon.xyz
# https://hachyderm.io/@collinbanko              collinbanko@hachyderm.io
# https://starside.social/@beorn                    beorn@starside.social
# https://mastodon.social/@shourijo              shourijo@mastodon.social
# https://iconfactory.world/@support                              support
#
#                                                 display_name locked    bot  \
# https://mastodon.social/@Gargron                Eugen Rochko  False  False
# https://mastodon.social/@thedextriarchy        Adi Robertson  False  False
# https://mastodon.online/@darth                        darth™  False  False
# https://mastodon.online/@justinling            Justin Ling🆒️  False  False
# https://c18.masto.host/@grubstreetwomen          Kate Ozment  False  False
# ...                                                      ...    ...    ...
# https://mastodon.xyz/@Ashkendo                     Ash Doyle  False  False
# https://hachyderm.io/@collinbanko               Collin Banko  False  False
# https://starside.social/@beorn                  Michael Lake  False  False
# https://mastodon.social/@shourijo                             False  False
# https://iconfactory.world/@support       Iconfactory Support  False  False
#
#                                         discoverable  group  \
# https://mastodon.social/@Gargron                True  False
# https://mastodon.social/@thedextriarchy         True  False
# https://mastodon.online/@darth                  True  False
# https://mastodon.online/@justinling             True  False
# https://c18.masto.host/@grubstreetwomen         True  False
# ...                                              ...    ...
# https://mastodon.xyz/@Ashkendo                  True  False
# https://hachyderm.io/@collinbanko               True  False
# https://starside.social/@beorn                  True  False
# https://mastodon.social/@shourijo              False  False
# https://iconfactory.world/@support              True  False
#
#                                                        created_at  \
# https://mastodon.social/@Gargron         2016-03-16T00:00:00.000Z
# https://mastodon.social/@thedextriarchy  2017-11-02T00:00:00.000Z
# https://mastodon.online/@darth           2023-03-28T00:00:00.000Z
# https://mastodon.online/@justinling      2022-04-29T00:00:00.000Z
# https://c18.masto.host/@grubstreetwomen  2023-03-28T00:00:00.000Z
# ...                                                           ...
# https://mastodon.xyz/@Ashkendo           2017-04-04T00:00:00.000Z
# https://hachyderm.io/@collinbanko        2022-11-22T00:00:00.000Z
# https://starside.social/@beorn           2022-12-19T00:00:00.000Z
# https://mastodon.social/@shourijo        2018-08-23T00:00:00.000Z
# https://iconfactory.world/@support       2023-01-23T00:00:00.000Z
#
#                                                                                       note  \
# https://mastodon.social/@Gargron         <p>Founder, CEO and lead developer <span class...
# https://mastodon.social/@thedextriarchy  <p>Senior tech &amp; policy editor, The Verge</p>
# https://mastodon.online/@darth                      <p>not the darth u are looking for</p>
# https://mastodon.online/@justinling      <p>Freelance investigative journalist — nation...
# https://c18.masto.host/@grubstreetwomen  <p>Assistant professor of English; <a href="ht...
# ...                                                                                    ...
# https://mastodon.xyz/@Ashkendo           <p>introvert, IT worker, amateur/wannabe comic...
# https://hachyderm.io/@collinbanko        <p>Virtual Production Pipeline Engineer with L...
# https://starside.social/@beorn           <p><a href="https://starside.social/tags/NorCa...
# https://mastodon.social/@shourijo
# https://iconfactory.world/@support       <p>Technical support for the Iconfactory&#39;s...
#
#                                          ... statuses_count last_status_at  \
# https://mastodon.social/@Gargron         ...          73481     2023-03-30
# https://mastodon.social/@thedextriarchy  ...            556     2023-04-11
# https://mastodon.online/@darth           ...             92     2023-04-11
# https://mastodon.online/@justinling      ...            394     2023-04-11
# https://c18.masto.host/@grubstreetwomen  ...             19     2023-04-10
# ...                                      ...            ...            ...
# https://mastodon.xyz/@Ashkendo           ...           1478     2023-04-10
# https://hachyderm.io/@collinbanko        ...              0           None
# https://starside.social/@beorn           ...             98     2023-04-02
# https://mastodon.social/@shourijo        ...              0           None
# https://iconfactory.world/@support       ...              0           None
#
#                                         noindex  \
# https://mastodon.social/@Gargron          False
# https://mastodon.social/@thedextriarchy   False
# https://mastodon.online/@darth              NaN
# https://mastodon.online/@justinling         NaN
# https://c18.masto.host/@grubstreetwomen     NaN
# ...                                         ...
# https://mastodon.xyz/@Ashkendo              NaN
# https://hachyderm.io/@collinbanko           NaN
# https://starside.social/@beorn              NaN
# https://mastodon.social/@shourijo           NaN
# https://iconfactory.world/@support        False
#
#                                                                                     emojis  \
# https://mastodon.social/@Gargron                                                        []
# https://mastodon.social/@thedextriarchy                                                 []
# https://mastodon.online/@darth                                                          []
# https://mastodon.online/@justinling                                                     []
# https://c18.masto.host/@grubstreetwomen                                                 []
# ...                                                                                    ...
# https://mastodon.xyz/@Ashkendo                                                          []
# https://hachyderm.io/@collinbanko                                                       []
# https://starside.social/@beorn           [{'shortcode': 'jaderabbit', 'url': 'https://i...
# https://mastodon.social/@shourijo                                                       []
# https://iconfactory.world/@support                                                      []
#
#                                         roles  \
# https://mastodon.social/@Gargron           []
# https://mastodon.social/@thedextriarchy    []
# https://mastodon.online/@darth            NaN
# https://mastodon.online/@justinling       NaN
# https://c18.masto.host/@grubstreetwomen   NaN
# ...                                       ...
# https://mastodon.xyz/@Ashkendo            NaN
# https://hachyderm.io/@collinbanko         NaN
# https://starside.social/@beorn            NaN
# https://mastodon.social/@shourijo         NaN
# https://iconfactory.world/@support        NaN
#
#                                                                                     fields  \
# https://mastodon.social/@Gargron         [{'name': 'Patreon', 'value': '<a href="https:...
# https://mastodon.social/@thedextriarchy  [{'name': 'Twitter', 'value': '<a href="https:...
# https://mastodon.online/@darth                                                          []
# https://mastodon.online/@justinling      [{'name': 'Website', 'value': '<a href="https:...
# https://c18.masto.host/@grubstreetwomen                                                 []
# ...                                                                                    ...
# https://mastodon.xyz/@Ashkendo           [{'name': 'Location', 'value': 'Wilson, NC', '...
# https://hachyderm.io/@collinbanko        [{'name': 'Pronouns', 'value': 'he/him/his', '...
# https://starside.social/@beorn           [{'name': 'Photography', 'value': '<a href="ht...
# https://mastodon.social/@shourijo                                                       []
# https://iconfactory.world/@support       [{'name': 'FAQ', 'value': '<a href="https://su...
#
#                                         suspended moved limited role
# https://mastodon.social/@Gargron              NaN   NaN     NaN  NaN
# https://mastodon.social/@thedextriarchy       NaN   NaN     NaN  NaN
# https://mastodon.online/@darth                NaN   NaN     NaN  NaN
# https://mastodon.online/@justinling           NaN   NaN     NaN  NaN
# https://c18.masto.host/@grubstreetwomen       NaN   NaN     NaN  NaN
# ...                                           ...   ...     ...  ...
# https://mastodon.xyz/@Ashkendo                NaN   NaN     NaN  NaN
# https://hachyderm.io/@collinbanko             NaN   NaN     NaN  NaN
# https://starside.social/@beorn                NaN   NaN     NaN  NaN
# https://mastodon.social/@shourijo             NaN   NaN     NaN  NaN
# https://iconfactory.world/@support            NaN   NaN     NaN  NaN
#
# [85268 rows x 27 columns]

# %%
df.columns
# Out:
# Index(['id', 'username', 'acct', 'display_name', 'locked', 'bot',
#        'discoverable', 'group', 'created_at', 'note', 'url', 'avatar',
#        'avatar_static', 'header', 'header_static', 'followers_count',
#        'following_count', 'statuses_count', 'last_status_at', 'noindex',
#        'emojis', 'roles', 'fields', 'suspended', 'moved', 'limited', 'role'],
#       dtype='object')
